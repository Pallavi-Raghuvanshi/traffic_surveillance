# %%
import config as c

# %%
a = c.Config()
print(a)
# Out:
# (path='C:\Minor Project\traffic_surveillance\track1\configs\config.yaml')

# %%
a.__repr__()
# Out:
# "(path='C:\\Minor Project\\traffic_surveillance\\track1\\configs\\config.yaml')"

# %%
print(a.__class__)
print(a.__class__.__name__)
# Out:
# <class 'config.Config'>
# Config

# %%
import cv2

# %%
f = cv2.VideoCapture('C:\Minor Project\traffic_surveillance\track1\data\raw\sample.avi')

# %%
f
# Out:
# < cv2.VideoCapture 000001F4459B7950>

# %%
f
# Out:
# < cv2.VideoCapture 000001F4459B7950>

# %%
cv2.imread(f)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cv2.imread(f)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
